# %%
# Data Analytics imports
import pandas as pd
import numpy as np

#Loading the CSV of the default dataset
df = pd.read_csv(r'C:\Users\mmorg\Desktop\ratingsdump-clbsc.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12884 entries, 0 to 12883
# Data columns (total 83 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         12884 non-null  int64
#  1   Name       12884 non-null  object
#  2   Pos        12884 non-null  object
#  3   League     12884 non-null  int64
#  4   Team       12884 non-null  int64
#  5   Org        12884 non-null  int64
#  6   LgLvl      12098 non-null  float64
#  7   Age        12884 non-null  int64
#  8   Height     12884 non-null  int64
#  9   Bats       12884 non-null  object
#  10  Throws     12884 non-null  object
#  11  Cntct      12884 non-null  int64
#  12  Gap        12884 non-null  int64
#  13  Pow        12884 non-null  int64
#  14  Eye        12884 non-null  int64
#  15  Ks         12884 non-null  int64
#  16  PotCntct   12884 non-null  int64
#  17  PotGap     12884 non-null  int64
#  18  PotPow     12884 non-null  int64
# ...

# %%
df_bat = df[['Pos', 'Name', 'LgLvl', 'Age', 'Height', 'Bats', 'Cntct', 'PotCntct', 'Gap', 'PotGap', 'Pow', 'PotPow', 'Eye', 'PotEye', 'Ks', 'PotKs', 'CAb', 'CArm', 'IFR', 'IFE', 'IFA', 'TDP', 'OFR', 'OFE', 'OFA']]

df_pitch = df[['Pos', 'Name', 'LgLvl', 'Age', 'Height', 'Throws', 'Stf', 'Mov', 'Ctrl', 'PotStf', 'PotMov', 'PotCtrl', 'Vel', 'Stm', 'GB', 'Hold']]

df_bat.info()

df_pitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12884 entries, 0 to 12883
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pos       12884 non-null  object
#  1   Name      12884 non-null  object
#  2   LgLvl     12098 non-null  float64
#  3   Age       12884 non-null  int64
#  4   Height    12884 non-null  int64
#  5   Bats      12884 non-null  object
#  6   Cntct     12884 non-null  int64
#  7   PotCntct  12884 non-null  int64
#  8   Gap       12884 non-null  int64
#  9   PotGap    12884 non-null  int64
#  10  Pow       12884 non-null  int64
#  11  PotPow    12884 non-null  int64
#  12  Eye       12884 non-null  int64
#  13  PotEye    12884 non-null  int64
#  14  Ks        12884 non-null  int64
#  15  PotKs     12884 non-null  int64
#  16  CAb       12884 non-null  int64
#  17  CArm      12884 non-null  int64
#  18  IFR       12884 non-null  int64
#  19  IFE       12884 non-null  int64
# ...

# %%
df_bat.loc[:,['Pos', 'Name', 'LgLvl', 'Age', 'Height', 'Bats', 'Cntct', 'PotCntct', 'Gap', 'PotGap', 'Pow', 'PotPow', 'Eye', 'PotEye', 'Ks', 'PotKs', 'CAb', 'CArm', 'IFR', 'IFE', 'IFA', 'TDP', 'OFR', 'OFE', 'OFA']]

df_bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12884 entries, 0 to 12883
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pos       12884 non-null  object
#  1   Name      12884 non-null  object
#  2   LgLvl     12098 non-null  float64
#  3   Age       12884 non-null  int64
#  4   Height    12884 non-null  int64
#  5   Bats      12884 non-null  object
#  6   Cntct     12884 non-null  int64
#  7   PotCntct  12884 non-null  int64
#  8   Gap       12884 non-null  int64
#  9   PotGap    12884 non-null  int64
#  10  Pow       12884 non-null  int64
#  11  PotPow    12884 non-null  int64
#  12  Eye       12884 non-null  int64
#  13  PotEye    12884 non-null  int64
#  14  Ks        12884 non-null  int64
#  15  PotKs     12884 non-null  int64
#  16  CAb       12884 non-null  int64
#  17  CArm      12884 non-null  int64
#  18  IFR       12884 non-null  int64
#  19  IFE       12884 non-null  int64
# ...

# %%
df_pitch.loc[:,['Pos', 'Name', 'LgLvl', 'Age', 'Height', 'Throws', 'Stf', 'Mov', 'Ctrl', 'PotStf', 'PotMov', 'PotCtrl', 'Vel', 'Stm', 'GB', 'Hold']]

df_pitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12884 entries, 0 to 12883
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Pos      12884 non-null  object
#  1   Name     12884 non-null  object
#  2   LgLvl    12098 non-null  float64
#  3   Age      12884 non-null  int64
#  4   Height   12884 non-null  int64
#  5   Throws   12884 non-null  object
#  6   Stf      12884 non-null  int64
#  7   Mov      12884 non-null  int64
#  8   Ctrl     12884 non-null  int64
#  9   PotStf   12884 non-null  int64
#  10  PotMov   12884 non-null  int64
#  11  PotCtrl  12884 non-null  int64
#  12  Vel      12884 non-null  object
#  13  Stm      12884 non-null  int64
#  14  GB       12884 non-null  int64
#  15  Hold     12884 non-null  int64
# dtypes: float64(1), int64(11), object(4)
# memory usage: 1.6+ MB

# %%
# Provide a copy of the cleaned Data Set
df_bat.to_csv(r'C:\Users\mmorg\Desktop\batterratings.csv')

# %%
# Provide a copy of the cleaned Data Set
df_pitch.to_csv(r'C:\Users\mmorg\Desktop\pitcherratings.csv')
